# %% [markdown]
# # Project 8 -- Atulya Kadur

# %% [markdown]
# ## Question 1

# %%
import pandas as pd

# %%
myDF = pd.read_parquet('/anvil/projects/tdm/data/whin/weather.parquet')

# %%
myDF.head()
# Out:
#    station_id  latitude  longitude             name      observation_time  \
# 0           1  40.93894  -86.47418  WHIN001-PULA001  2019-07-10T04:00:00Z
# 1           1  40.93894  -86.47418  WHIN001-PULA001  2019-07-10T04:15:00Z
# 2           1  40.93894  -86.47418  WHIN001-PULA001  2019-07-11T04:00:00Z
# 3           1  40.93894  -86.47418  WHIN001-PULA001  2019-07-11T04:15:00Z
# 4           1  40.93894  -86.47418  WHIN001-PULA001  2019-07-11T04:30:00Z
#
#    temperature  temperature_high  temperature_low  humidity  solar_radiation  \
# 0         70.0              71.0             70.0      83.0              NaN
# 1         69.0              70.0             69.0      84.0              NaN
# 2         76.0              77.0             76.0      76.0              NaN
# 3         76.0              76.0             76.0      77.0              NaN
# 4         76.0              76.0             76.0      77.0              NaN
#
# ...

# %%
myDF['observation_time'] = pd.to_datetime(myDF['observation_time'])

# %%
myDF.head()
# Out:
#    station_id  latitude  longitude             name          observation_time  \
# 0           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-10 04:00:00+00:00
# 1           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-10 04:15:00+00:00
# 2           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:00:00+00:00
# 3           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:15:00+00:00
# 4           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:30:00+00:00
#
#    temperature  temperature_high  temperature_low  humidity  solar_radiation  \
# 0         70.0              71.0             70.0      83.0              NaN
# 1         69.0              70.0             69.0      84.0              NaN
# 2         76.0              77.0             76.0      76.0              NaN
# 3         76.0              76.0             76.0      77.0              NaN
# 4         76.0              76.0             76.0      77.0              NaN
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
myDF.head()
# Out:
#    station_id  latitude  longitude             name          observation_time  \
# 0           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-10 04:00:00+00:00
# 1           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-10 04:15:00+00:00
# 2           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:00:00+00:00
# 3           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:15:00+00:00
# 4           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:30:00+00:00
#
#    temperature  temperature_high  temperature_low  humidity  solar_radiation  \
# 0         70.0              71.0             70.0      83.0              NaN
# 1         69.0              70.0             69.0      84.0              NaN
# 2         76.0              77.0             76.0      76.0              NaN
# 3         76.0              76.0             76.0      77.0              NaN
# 4         76.0              76.0             76.0      77.0              NaN
#
# ...

# %%
myDF['day'] = myDF['observation_time'].dt.day
myDF['month'] = myDF['observation_time'].dt.month
myDF['year'] = myDF['observation_time'].dt.year

# %%
myDF.head()
# Out:
#    station_id  latitude  longitude             name          observation_time  \
# 0           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-10 04:00:00+00:00
# 1           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-10 04:15:00+00:00
# 2           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:00:00+00:00
# 3           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:15:00+00:00
# 4           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:30:00+00:00
#
#    temperature  temperature_high  temperature_low  humidity  solar_radiation  \
# 0         70.0              71.0             70.0      83.0              NaN
# 1         69.0              70.0             69.0      84.0              NaN
# 2         76.0              77.0             76.0      76.0              NaN
# 3         76.0              76.0             76.0      77.0              NaN
# 4         76.0              76.0             76.0      77.0              NaN
#
# ...

# %%
myDF['station_id'].value_counts()
# Out:
# station_id
# 4      71795
# 5      71789
# 3      71785
# 129    71784
# 128    71779
#        ...
# 190     7735
# 121     7491
# 189     7431
# 197     5804
# 67      4880
# Name: count, Length: 152, dtype: int64

# %%
myDF[myDF['station_id'] == 1].groupby(['year','month'])['temperature'].mean()
# Out:
# year  month
# 2019  7         1.699000
#       8        58.450756
#       9        68.906912
#       10       53.950605
#       11       35.828114
#       12       34.838319
# 2020  1        32.782521
#       2        30.199713
#       3        42.102590
#       4        48.237153
#       5        60.180444
#       6        73.109375
#       7        76.111970
#       8        71.325480
#       9        64.010424
#       10       51.814454
#       11       46.175652
#       12       32.706989
# 2021  1        29.468571
#       2        21.116115
#       3        44.176194
#       4        50.613834
#       5        59.466555
#       6        73.381730
#       7        72.553822
# Name: temperature, dtype: float64

# %%
myDF[myDF['station_id'] == 3].groupby(['year','month'])['temperature'].mean()
# Out:
# year  month
# 2019  7        75.180500
#       8        71.561008
#       9        69.971865
#       10       53.778675
#       11       35.788943
#       12       35.198925
# 2020  1        32.490084
#       2        30.007902
#       3        42.293999
#       4        48.614236
#       5        60.453293
#       6        73.259118
#       7        75.462366
#       8        71.006720
#       9        64.216319
#       10       51.790659
#       11       46.533380
#       12       32.646723
# 2021  1        29.356183
#       2        20.426126
#       3        44.336584
#       4        51.529861
#       5        60.045042
#       6        73.576042
#       7        72.650096
# Name: temperature, dtype: float64

# %%
myDF[myDF['station_id'] == 4].groupby(['year','month'])['temperature'].mean()
# Out:
# year  month
# 2019  7        75.552000
#       8        71.676303
#       9        70.550347
#       10       54.956975
#       11       36.762517
#       12       36.090726
# 2020  1        33.732637
#       2        32.004310
#       3        44.396639
#       4        49.790407
#       5        60.540195
#       6        73.299618
#       7        75.562036
#       8        71.237983
#       9        64.840348
#       10       53.085378
#       11       47.310924
#       12       33.424059
# 2021  1        30.453598
#       2        23.408954
#       3        45.759745
#       4        52.482986
#       5        60.622521
#       6        73.619660
#       7        73.011841
# Name: temperature, dtype: float64

# %%
my_station_id = 4
myDF[myDF['station_id'] == my_station_id].groupby(['year','month'])['temperature'].mean()
# Out:
# year  month
# 2019  7        75.552000
#       8        71.676303
#       9        70.550347
#       10       54.956975
#       11       36.762517
#       12       36.090726
# 2020  1        33.732637
#       2        32.004310
#       3        44.396639
#       4        49.790407
#       5        60.540195
#       6        73.299618
#       7        75.562036
#       8        71.237983
#       9        64.840348
#       10       53.085378
#       11       47.310924
#       12       33.424059
# 2021  1        30.453598
#       2        23.408954
#       3        45.759745
#       4        52.482986
#       5        60.622521
#       6        73.619660
#       7        73.011841
# Name: temperature, dtype: float64

# %%
def get_avg_temp(station_id_temp):
    return myDF[myDF['station_id'] == station_id_temp].groupby(['year','month'])['temperature'].mean()
get_avg_temp(4)
# Out:
# year  month
# 2019  7        75.552000
#       8        71.676303
#       9        70.550347
#       10       54.956975
#       11       36.762517
#       12       36.090726
# 2020  1        33.732637
#       2        32.004310
#       3        44.396639
#       4        49.790407
#       5        60.540195
#       6        73.299618
#       7        75.562036
#       8        71.237983
#       9        64.840348
#       10       53.085378
#       11       47.310924
#       12       33.424059
# 2021  1        30.453598
#       2        23.408954
#       3        45.759745
#       4        52.482986
#       5        60.622521
#       6        73.619660
#       7        73.011841
# Name: temperature, dtype: float64

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 2

# %%
import matplotlib.pyplot as plt

# %%
station_id_temp = 1
my_results = myDF[myDF['station_id'] == station_id_temp].groupby(['year','month'])['temperature'].mean()

# %%
my_results.unstack(0).plot(kind = 'line')
plt.title('line plot of temperature by year')
plt.xlabel('month')
plt.ylabel('temperature')
#plt.xticks(range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
# Out:
# Text(0, 0.5, 'temperature')

# %%
station_id_temp = 3
my_results = myDF[myDF['station_id'] == station_id_temp].groupby(['year','month'])['temperature'].mean()
my_results.unstack(0).plot(kind = 'line')
plt.title('line plot of temperature by year')
plt.xlabel('month')
plt.ylabel('temperature')
# Out:
# Text(0, 0.5, 'temperature')

# %%
station_id_temp = 4
my_results = myDF[myDF['station_id'] == station_id_temp].groupby(['year','month'])['temperature'].mean()
my_results.unstack(0).plot(kind = 'line')
plt.title('line plot of temperature by year')
plt.xlabel('month')
plt.ylabel('temperature')
# Out:
# Text(0, 0.5, 'temperature')

# %%
def line_plot(station_id_temp):
    my_results = myDF[myDF['station_id'] == station_id_temp].groupby(['year','month'])['temperature'].mean()
    my_results.unstack(0).plot(kind = 'line')
line_plot(1)
plt.title('line plot of temperature by year')
plt.xlabel('month')
plt.ylabel('temperature')
# Out:
# Text(0, 0.5, 'temperature')

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 3

# %%
def get_max_temp(station_id_temp):
    return myDF[myDF['station_id'] == station_id_temp].groupby(['year','month'])['temperature'].max()
get_max_temp(1)
# Out:
# year  month
# 2019  7        90.0
#       8        89.0
#       9        90.0
#       10       91.0
#       11       58.0
#       12       64.0
# 2020  1        58.0
#       2        59.0
#       3        66.0
#       4        79.0
#       5        90.0
#       6        92.0
#       7        94.0
#       8        92.0
#       9        86.0
#       10       83.0
#       11       79.0
#       12       57.0
# 2021  1        46.0
#       2        60.0
#       3        71.0
#       4        82.0
#       5        87.0
#       6        94.0
#       7        89.0
# Name: temperature, dtype: float64

# %%
myDF[myDF['station_id'] == 1].groupby(['year','month'])['temperature'].max()
# Out:
# year  month
# 2019  7        90.0
#       8        89.0
#       9        90.0
#       10       91.0
#       11       58.0
#       12       64.0
# 2020  1        58.0
#       2        59.0
#       3        66.0
#       4        79.0
#       5        90.0
#       6        92.0
#       7        94.0
#       8        92.0
#       9        86.0
#       10       83.0
#       11       79.0
#       12       57.0
# 2021  1        46.0
#       2        60.0
#       3        71.0
#       4        82.0
#       5        87.0
#       6        94.0
#       7        89.0
# Name: temperature, dtype: float64

# %%
myDF[myDF['station_id'] == 3].groupby(['year','month'])['temperature'].max()
# Out:
# year  month
# 2019  7        94.0
#       8        90.0
#       9        92.0
#       10       91.0
#       11       57.0
#       12       63.0
# 2020  1        59.0
#       2        59.0
#       3        67.0
#       4        79.0
#       5        89.0
#       6        94.0
#       7        92.0
#       8        91.0
#       9        86.0
#       10       83.0
#       11       78.0
#       12       59.0
# 2021  1        46.0
#       2        60.0
#       3        72.0
#       4        84.0
#       5        89.0
#       6        95.0
#       7        88.0
# Name: temperature, dtype: float64

# %%
def bar_plot(station_id_temp):
    my_results = myDF[myDF['station_id'] == station_id_temp].groupby(['year','month'])['temperature'].max()
    my_results.unstack(0).plot(kind = 'bar')
bar_plot(1)
plt.title('line plot of temperature by year')
plt.xlabel('month')
plt.ylabel('temperature')
# Out:
# Text(0, 0.5, 'temperature')

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 4

# %%
station_id_temp = 1
my_year = 2020
my_results = myDF[(myDF['station_id'] == station_id_temp) & (myDF['year'] == my_year)]
my_results.boxplot(column = 'wind_speed_mph', by = 'month')
plt.title('box plot of wind speed by year')
plt.xlabel('month')
plt.ylabel('wind speed ')
# Out:
# Text(0, 0.5, 'wind speed ')

# %%
def boxplot(my_year, station_id_temp):
    my_results = myDF[(myDF['station_id'] == station_id_temp) & (myDF['year'] == my_year)]
    my_results.boxplot(column = 'wind_speed_mph', by = 'month')
boxplot(2019, 3)
plt.title('box plot of wind speed by year')
plt.xlabel('month')
plt.ylabel('wind speed ')
# Out:
# Text(0, 0.5, 'wind speed ')

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %%
myDF[myDF['station_id'] == 1].groupby(['year','month'])['pressure'].mean()
# Out:
# year  month
# 2019  7        30.141803
#       8        30.015603
#       9        30.067259
#       10       30.029372
#       11       30.156346
#       12       30.096489
# 2020  1        30.180059
#       2        30.144660
#       3        30.139524
#       4        29.965624
#       5        30.039818
#       6        30.006410
#       7        29.994808
#       8        30.011262
#       9        30.088935
#       10       30.114227
#       11       30.174874
#       12       30.104848
# 2021  1        30.132733
#       2        30.236721
#       3        30.188890
#       4        30.002624
#       5        30.156469
#       6        29.984072
#       7        30.049340
# Name: pressure, dtype: float64

# %%
my_results = myDF[myDF['station_id'] == 1].groupby(['year','month'])['pressure'].mean()
my_results.unstack(0).plot(kind = 'line')
plt.title('line plot of pressure by year')
plt.xlabel('month')
plt.ylabel('wind speed ')
# Out:
# Text(0, 0.5, 'wind speed ')

# %%
def pressure_by_year(station_id_temp):
    my_results = myDF[myDF['station_id'] == station_id_temp].groupby(['year','month'])['pressure'].mean()
    return my_results

# %%
pressure_by_year(1)
# Out:
# year  month
# 2019  7        30.141803
#       8        30.015603
#       9        30.067259
#       10       30.029372
#       11       30.156346
#       12       30.096489
# 2020  1        30.180059
#       2        30.144660
#       3        30.139524
#       4        29.965624
#       5        30.039818
#       6        30.006410
#       7        29.994808
#       8        30.011262
#       9        30.088935
#       10       30.114227
#       11       30.174874
#       12       30.104848
# 2021  1        30.132733
#       2        30.236721
#       3        30.188890
#       4        30.002624
#       5        30.156469
#       6        29.984072
#       7        30.049340
# Name: pressure, dtype: float64

# %%
def pressure_by_year_plot(station_id_temp):
    my_results = myDF[myDF['station_id'] == station_id_temp].groupby(['year','month'])['pressure'].mean()
    plt.title('line plot of pressure by year')
    plt.xlabel('month')
    plt.ylabel('wind speed ')
    my_results.unstack(0).plot(kind = 'line')

# %%
pressure_by_year_plot(4)

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
